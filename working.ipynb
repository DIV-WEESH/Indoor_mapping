# %% [markdown]
# # Working

# %% [markdown]
# 1.Upload your floor plan image <BR>
# 2 Set scale by clicking 2 points <BR>
# 3 Add hallways as your main paths <BR>
# 4 Add rooms and connect to hallways <BR>
# 5 Save and test <BR>

# %% [markdown]
# ![img2.png](attachment:img2.png)

# %% [markdown]
# ![Screenshot 2026-01-14 145258.png](<attachment:Screenshot 2026-01-14 145258.png>)

# %% [markdown]
# ![Screenshot 2026-01-14 145321.png](<attachment:Screenshot 2026-01-14 145321.png>)
